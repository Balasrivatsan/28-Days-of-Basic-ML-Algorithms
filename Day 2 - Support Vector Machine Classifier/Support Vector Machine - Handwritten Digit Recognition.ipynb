# %% [markdown]
# Importing Libraries

# %%
import numpy as np
from sklearn.datasets import load_digits

# %% [markdown]
# Importing the Dataset

# %%
df = load_digits()

# %% [markdown]
# Summarizing the Dataset

# %%
print(df.data)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
print(df.target)
# Out:
# [0 1 2 ... 8 9 8]

# %%
print(df.data.shape)
# Out:
# (1797, 64)

# %%
print(df.images.shape)
# Out:
# (1797, 8, 8)

# %%
datasetimagelength = len(df.images)
print(datasetimagelength)
# Out:
# 1797

# %% [markdown]
# Visualizing the Image

# %%
n = 1001 #number denoting the nth image in dataset

print("Image matrix: ")
print(df.images[n])

print("\nImage:")
import matplotlib.pyplot as plt
plt.gray()
plt.matshow(df.images[n])
plt.show()
# Out:
# Image matrix:
# [[ 0.  0.  0.  1. 15.  2.  0.  0.]
#  [ 0.  0.  0.  5. 15.  0.  4.  0.]
#  [ 0.  0.  0. 13.  8.  1. 16.  3.]
#  [ 0.  0.  5. 15.  2.  5. 15.  0.]
#  [ 0.  5. 15. 16. 16. 16.  8.  0.]
#  [ 0. 14. 12. 12. 14. 16.  2.  0.]
#  [ 0.  0.  0.  0. 12. 12.  0.  0.]
#  [ 0.  0.  0.  2. 16.  5.  0.  0.]]
#
# Image:

# %% [markdown]
# Segregating the Dataset into X and Y

# %%
X = df.images.reshape((datasetimagelength, -1))
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
Y = df.target
Y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %% [markdown]
# Splitting the Dataset into Training and Testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1347, 64)
# (450, 64)

# %% [markdown]
# Training the Model

# %%
from sklearn import svm
model = svm.SVC(kernel = 'linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Predicting the Digit from Test Data

# %%
n = 1700
result = model.predict(df.images[n].reshape((1, -1)))
plt.imshow(df.images[n], cmap = plt.cm.gray_r, interpolation = 'nearest')
print(result)
print('\n')
plt.axis('off')
plt.title('%i' %result.item())
plt.show()
# Out:
# [5]

# %% [markdown]
# Predicting the Test Data

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.reshape(len(y_test), 1)), 1))
# Out:
# [[2 2]
#  [8 8]
#  [2 2]
#  [6 6]
#  [6 6]
#  [7 7]
#  [1 1]
#  [9 9]
#  [8 8]
#  [5 5]
#  [2 2]
#  [8 8]
#  [6 6]
#  [6 6]
#  [6 6]
#  [6 6]
#  [1 1]
#  [0 0]
#  [5 5]
#  [8 8]
#  [8 8]
#  [7 7]
#  [8 8]
#  [4 4]
#  [7 7]
#  [5 5]
#  [4 4]
#  [9 9]
#  [2 2]
#  [9 9]
#  [4 4]
#  [7 7]
#  [6 6]
#  [8 8]
#  [9 9]
#  [4 4]
#  [3 3]
#  [1 1]
#  [0 0]
#  [1 1]
#  [8 8]
#  [6 6]
#  [7 7]
#  [7 7]
#  [1 1]
#  [0 0]
#  [7 7]
#  [6 6]
#  [2 2]
#  [1 1]
#  [9 9]
#  [6 6]
#  [7 7]
#  [9 9]
#  [0 0]
#  [0 0]
#  [5 5]
#  [1 1]
#  [6 6]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [4 4]
#  [1 1]
#  [9 9]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [8 8]
#  [3 3]
#  [5 5]
#  [1 1]
#  [2 2]
#  [8 8]
#  [2 2]
#  [2 2]
#  [9 9]
#  [7 7]
#  [2 2]
#  [3 3]
#  [6 6]
#  [0 0]
#  [5 5]
#  [3 3]
#  [7 7]
#  [5 5]
#  [1 1]
#  [2 2]
#  [9 9]
#  [9 9]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [4 4]
#  [8 8]
#  [5 5]
#  [8 8]
#  [5 5]
#  [5 5]
#  [2 2]
#  [5 5]
#  [9 9]
#  [0 0]
#  [7 7]
#  [1 1]
#  [4 4]
#  [4 7]
#  [3 3]
# ...

# %% [markdown]
# Evaluating the Model Performance

# %%
from sklearn.metrics import accuracy_score
print("Accuracy of the Model: {0}".format(accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy of the Model: 97.11111111111111

# %% [markdown]
# Using other Types of SVC

# %%
from sklearn import svm
model1 = svm.SVC(kernel='linear') #Default gamma = 0.1 and  C = 1.0
model2 = svm.SVC(kernel='rbf') #Default gamma = 0.1 and  C = 1.0
model3 = svm.SVC(gamma=0.001) #Uses RBF kernel by default along with the specified value of Gamma and C
model4 = svm.SVC(gamma=0.001,C=0.1) #Uses RBF kernel by default

model1.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)
model4.fit(X_train,y_train)

y_predModel1 = model1.predict(X_test)
y_predModel2 = model2.predict(X_test)
y_predModel3 = model3.predict(X_test)
y_predModel4 = model4.predict(X_test)

print("Accuracy of the Model 1: {0}%".format(accuracy_score(y_test, y_predModel1)*100))
print("Accuracy of the Model 2: {0}%".format(accuracy_score(y_test, y_predModel2)*100))
print("Accuracy of the Model 3: {0}%".format(accuracy_score(y_test, y_predModel3)*100))
print("Accuracy of the Model 4: {0}%".format(accuracy_score(y_test, y_predModel4)*100))
# Out:
# Accuracy of the Model 1: 97.11111111111111%
# Accuracy of the Model 2: 99.11111111111111%
# Accuracy of the Model 3: 99.55555555555556%
# Accuracy of the Model 4: 96.66666666666667%
